# %%
import pandas as pd
df = pd.read_csv("employee.csv")
print(df)
# Out:
#     EmployeeID     Name Department  Salary  Experience  Age       City  \
# 0          101    Rahul         IT   50000           2   24    Chennai
# 1          102    Priya         HR   45000           3   26  Bangalore
# 2          103     Arun    Finance   60000           5   30  Hyderabad
# 3          104     Zara         IT   70000           7   32     Mumbai
# 4          105    Karan      Sales   55000           4   28      Delhi
# 5          106    Sneha         HR   48000           2   25    Chennai
# 6          107     Ajay    Finance   65000           6   31       Pune
# 7          108    Meena      Sales   52000           3   27  Bangalore
# 8          109     Ravi         IT   75000           8   34    Chennai
# 9          110   Anjali  Marketing   58000           4   29     Mumbai
# 10         111   Vikram      Sales   62000           5   30      Delhi
# 11         112    Divya         HR   47000           2   24    Chennai
# ...

# %%
print(df.head())
# Out:
#    EmployeeID   Name Department  Salary  Experience  Age       City  \
# 0         101  Rahul         IT   50000           2   24    Chennai
# 1         102  Priya         HR   45000           3   26  Bangalore
# 2         103   Arun    Finance   60000           5   30  Hyderabad
# 3         104   Zara         IT   70000           7   32     Mumbai
# 4         105  Karan      Sales   55000           4   28      Delhi
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12
# 0         NaN         NaN         NaN          NaN          NaN          NaN
# 1         NaN         NaN         NaN          NaN          NaN          NaN
# 2         NaN         NaN         NaN          NaN          NaN          NaN
# 3         NaN         NaN         NaN          NaN          NaN          NaN
# 4         NaN         NaN         NaN          NaN          NaN          NaN

# %%
print(df.tail())
# Out:
#     EmployeeID     Name Department  Salary  Experience  Age       City  \
# 15         116    Pooja         HR   49000           3   26     Mumbai
# 16         117    Manoj      Sales   56000           4   29      Delhi
# 17         118     Asha    Finance   64000           5   30    Chennai
# 18         119    Rohan  Marketing   61000           5   32       Pune
# 19         120  Keerthi         IT   78000           9   35  Hyderabad
#
#     Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12
# 15         NaN         NaN         NaN          NaN          NaN          NaN
# 16         NaN         NaN         NaN          NaN          NaN          NaN
# 17         NaN         NaN         NaN          NaN          NaN          NaN
# 18         NaN         NaN         NaN          NaN          NaN          NaN
# 19         NaN         NaN         NaN          NaN          NaN          NaN

# %%
print("\n Dataset Shape")
print(df.shape)
# Out:
#  Dataset Shape
# (20, 13)

# %%
print("\n Dataset Information")
df.info()
# Out:
#  Dataset Information
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EmployeeID   20 non-null     int64
#  1   Name         20 non-null     object
#  2   Department   20 non-null     object
#  3   Salary       20 non-null     int64
#  4   Experience   20 non-null     int64
#  5   Age          20 non-null     int64
#  6   City         20 non-null     object
#  7   Unnamed: 7   0 non-null      float64
#  8   Unnamed: 8   0 non-null      float64
#  9   Unnamed: 9   0 non-null      float64
#  10  Unnamed: 10  0 non-null      float64
#  11  Unnamed: 11  0 non-null      float64
#  12  Unnamed: 12  0 non-null      float64
# dtypes: float64(6), int64(4), object(3)
# memory usage: 2.2+ KB

# %%
salary_series = df["Salary"]
print(salary_series)
# Out:
# 0     50000
# 1     45000
# 2     60000
# 3     70000
# 4     55000
# 5     48000
# 6     65000
# 7     52000
# 8     75000
# 9     58000
# 10    62000
# 11    47000
# 12    68000
# 13    59000
# 14    72000
# 15    49000
# 16    56000
# 17    64000
# 18    61000
# 19    78000
# Name: Salary, dtype: int64

# %%
print("\n Employee name and salary")
print(df[["Name", "Salary"]])
# Out:
#  Employee name and salary
#        Name  Salary
# 0     Rahul   50000
# 1     Priya   45000
# 2      Arun   60000
# 3      Zara   70000
# 4     Karan   55000
# 5     Sneha   48000
# 6      Ajay   65000
# 7     Meena   52000
# 8      Ravi   75000
# 9    Anjali   58000
# 10   Vikram   62000
# 11    Divya   47000
# 12   Suresh   68000
# 13    Nisha   59000
# 14  Karthik   72000
# 15    Pooja   49000
# 16    Manoj   56000
# 17     Asha   64000
# 18    Rohan   61000
# 19  Keerthi   78000
